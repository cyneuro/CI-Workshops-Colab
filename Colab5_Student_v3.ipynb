# %% [markdown]
# # Colab5_Student_v3
# ## Studio 5: Scaling Scientific Workflows Using Cloud and HPC Resources

# %% [markdown]
# ### Learning Outcomes
# - Measure runtime and memory
# - Compare computing strategies
# - Explain cloud and HPC concepts
# - Evaluate scaling approaches
# - Analyze workflow performance

# %% [markdown]
# ## Workflow Narrative
# Scientific Question → Dataset → Analysis → Runtime Measurement → Resource Requirements → Scaling Strategy → Cloud/HPC Deployment → Benchmarking → Discovery

# %%
import pandas as pd, numpy as np, time, tracemalloc, matplotlib.pyplot as plt

# %% [markdown]
# ## Walkthrough A: Runtime Growth

# %%
sizes=[1000,10000,100000,1000000]
runtimes=[]
for n in sizes:
 import time
 start=time.time()
 sum(range(n))
 runtimes.append(time.time()-start)
print(list(zip(sizes,runtimes)))

# %% [markdown]
# What happens as problem size increases?

# %% [markdown]
# ## Walkthrough B: Scaling a Sleep Analytics Workflow

# %%
sleep=pd.DataFrame({'sleep_hours':[4,5,6,7,8,9]*1000,'attention':[52,58,66,74,82,89]*1000})
sleep.head()

# %%
sleep.describe()

# %% [markdown]
# ## Serial vs Parallel Computing

# %% [markdown]
# Complete the activity and record observations, evidence, and conclusions.

# %% [markdown]
# ## Runtime Benchmarking

# %% [markdown]
# Complete the activity and record observations, evidence, and conclusions.

# %% [markdown]
# ## Memory Profiling

# %% [markdown]
# Complete the activity and record observations, evidence, and conclusions.

# %% [markdown]
# ## Large Dataset Processing

# %% [markdown]
# Complete the activity and record observations, evidence, and conclusions.

# %% [markdown]
# ## Cloud Deployment Models

# %% [markdown]
# Complete the activity and record observations, evidence, and conclusions.

# %% [markdown]
# ## HPC Queues

# %% [markdown]
# Complete the activity and record observations, evidence, and conclusions.

# %% [markdown]
# ## Distributed Cyberinfrastructure

# %% [markdown]
# Complete the activity and record observations, evidence, and conclusions.

# %% [markdown]
# ## Scaling ML Workflows

# %% [markdown]
# Complete the activity and record observations, evidence, and conclusions.

# %%
tracemalloc.start(); x=np.random.randn(1000000); print('Peak Memory',tracemalloc.get_traced_memory()[1])

# %%
from sklearn.linear_model import LinearRegression
X=np.arange(1000).reshape(-1,1)
y=2*X.ravel()+1
model=LinearRegression().fit(X,y)
print(model.score(X,y))

# %% [markdown]
# ## Benchmarking Studio

# %% [markdown]
# Compare runtimes for datasets of different sizes.

# %% [markdown]
# ## Telemetry Studio

# %%
start=time.time(); _=sleep.describe(); print('Runtime',time.time()-start)

# %% [markdown]
# Record runtime, memory, and possible bottlenecks.

# %% [markdown]
# ## Cloud/HPC Decision Studio

# %% [markdown]
# When is a laptop sufficient? When might cloud or HPC resources be needed?

# %% [markdown]
# ## FABRIC, CloudLab, and Chameleon Concepts

# %% [markdown]
# Research the role of each platform in scientific workflows.

# %% [markdown]
# ## AI-Assisted Scaling Studio

# %% [markdown]
# Ask AI to recommend a scaling strategy. Critically evaluate the recommendation.

# %% [markdown]
# ### Reflection 1
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 2
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 3
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 4
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 5
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 6
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 7
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 8
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 9
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 10
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 11
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 12
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 13
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 14
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 15
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 16
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 17
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 18
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 19
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ### Reflection 20
# Observation:
# Evidence:
# Interpretation:
# Next Action:

# %% [markdown]
# ## Stretch Challenge
# Design a scalable workflow for Sleep Analytics, Attention Analytics, Neuro-Inspired Sensors, or Smart Campus Wellness.

# %% [markdown]
# ## Preview of Studio 6
# Machine Learning Workflows for Scientific Discovery
