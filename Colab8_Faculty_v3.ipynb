# %% [markdown]
# # Colab8_Faculty_v3
# ## Studio 8: FAIR, Provenance, Benchmarking, and Workflow Validation

# %% [markdown]
# Capstone studio integrating FAIR principles, provenance, benchmarking, validation, reproducibility engineering, and end-to-end workflow assessment.

# %% [markdown]
# Scientific Question → Data → Workflow → Results → FAIR Documentation → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ## Instructor Guide

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Learning Outcomes

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Teaching Narrative

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Studio Overview

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Walkthrough A FAIR Assessment

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Walkthrough B Provenance Tracking

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Worked Example 1 Findable Data

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Worked Example 2 Accessible Data

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Worked Example 3 Interoperable Data

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Worked Example 4 Reusable Data

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Worked Example 5 Provenance Records

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Worked Example 6 Benchmarking Scientific Workflows

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Worked Example 7 Workflow Validation

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Worked Example 8 Reproducibility Engineering

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## FAIR Studio

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Provenance Studio

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Benchmarking Studio

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Validation Studio

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Reproducibility Studio

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Capstone Workflow Review

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Portfolio Artifact Development

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## AI-Assisted Documentation Studio

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Telemetry Review Studio

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Rubrics

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## TA Notes

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Troubleshooting

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Online Delivery Notes

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Stretch Challenge

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %% [markdown]
# ## Advanced Topics and Future Directions

# %% [markdown]
# Faculty notes, solutions, assessment guidance, discussion prompts, and implementation recommendations.

# %%
metadata={'dataset':'Sleep Analytics','source':'Open Repository','version':'1.0','license':'CC-BY','variables':['sleep_hours','attention']}
metadata

# %%
import pandas as pd
provenance=pd.DataFrame({'stage':['raw','cleaned','analysis','figure','report'],'artifact':['data.csv','clean.csv','analysis.ipynb','figure.png','report.pdf']})
provenance

# %%
import pandas as pd, numpy as np, time, tracemalloc
df=pd.DataFrame({'x':np.random.randn(100000)})
tracemalloc.start(); start=time.time(); df.describe(); print({'runtime':time.time()-start,'peak_memory':tracemalloc.get_traced_memory()[1]})

# %%
validation={'inputs_documented':True,'outputs_documented':True,'versioned':True,'reproducible':True}
validation

# %% [markdown]
# ### Capstone Activity 1

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %%
import time; start=time.time(); x=sum(range(100000)); print({'runtime':time.time()-start})

# %% [markdown]
# ### Capstone Activity 2

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 3

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 4

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 5

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 6

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %%
import time; start=time.time(); x=sum(range(100000)); print({'runtime':time.time()-start})

# %% [markdown]
# ### Capstone Activity 7

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 8

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 9

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 10

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 11

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %%
import time; start=time.time(); x=sum(range(100000)); print({'runtime':time.time()-start})

# %% [markdown]
# ### Capstone Activity 12

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 13

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 14

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 15

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 16

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %%
import time; start=time.time(); x=sum(range(100000)); print({'runtime':time.time()-start})

# %% [markdown]
# ### Capstone Activity 17

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 18

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 19

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 20

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 21

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %%
import time; start=time.time(); x=sum(range(100000)); print({'runtime':time.time()-start})

# %% [markdown]
# ### Capstone Activity 22

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 23

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 24

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 25

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 26

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %%
import time; start=time.time(); x=sum(range(100000)); print({'runtime':time.time()-start})

# %% [markdown]
# ### Capstone Activity 27

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 28

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 29

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 30

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 31

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %%
import time; start=time.time(); x=sum(range(100000)); print({'runtime':time.time()-start})

# %% [markdown]
# ### Capstone Activity 32

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 33

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 34

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 35

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 36

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %%
import time; start=time.time(); x=sum(range(100000)); print({'runtime':time.time()-start})

# %% [markdown]
# ### Capstone Activity 37

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 38

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 39

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 40

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 41

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %%
import time; start=time.time(); x=sum(range(100000)); print({'runtime':time.time()-start})

# %% [markdown]
# ### Capstone Activity 42

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 43

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 44

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 45

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 46

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %%
import time; start=time.time(); x=sum(range(100000)); print({'runtime':time.time()-start})

# %% [markdown]
# ### Capstone Activity 47

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 48

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 49

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 50

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 51

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %%
import time; start=time.time(); x=sum(range(100000)); print({'runtime':time.time()-start})

# %% [markdown]
# ### Capstone Activity 52

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 53

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 54

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ### Capstone Activity 55

# %% [markdown]
# FAIR → Provenance → Benchmarking → Validation → Reproducibility → Reuse

# %% [markdown]
# ## Capstone Integration
# Evaluate Sleep Analytics, Attention Analytics, Neuro-Inspired Sensor, and Smart Campus Wellness workflows using FAIR, provenance, benchmarking, and validation criteria.
