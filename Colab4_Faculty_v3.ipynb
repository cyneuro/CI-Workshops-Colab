# %% [markdown]
# # Colab4_Faculty_v3
# ## Studio 4: Workflow Automation, Metadata, and Reproducible Research

# %% [markdown]
# Studio 4 focuses on workflow documentation, automation, metadata, provenance, validation, and reproducibility.

# %% [markdown]
# ### Workflow Narrative
# Scientific Question -> Data Discovery -> Data Acquisition -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ## Instructor Guide

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Learning Outcomes

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Teaching Narrative

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Studio Overview

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Walkthrough A Manual to Automated Workflow

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Walkthrough B Metadata Matters

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Worked Example 1 Manual vs Automated

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Worked Example 2 Workflow Decomposition

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Worked Example 3 Function-Based Automation

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Worked Example 4 Batch Processing

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Worked Example 5 Run Tracking

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Worked Example 6 Metadata Records

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Worked Example 7 AI Workflow Generation

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Worked Example 8 Reproducibility Evaluation

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Workflow Automation Studio

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Metadata Studio

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## AI Workflow Studio

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Provenance Studio

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Reproducibility Studio

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Telemetry Expansion

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Evidence-Based Communication

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## TA Notes

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Troubleshooting

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Online Delivery Notes

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Stretch Challenge

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %% [markdown]
# ## Advanced Topics and Future Directions

# %% [markdown]
# Faculty objectives, prompts, solutions, discussion notes, assessment guidance, and rubric references.

# %%
import pandas as pd, numpy as np, time, json

# %%
sleep=pd.DataFrame({'sleep_hours':[4,5,6,7,8,9],'attention':[52,58,66,74,82,89]}); sleep

# %%
def analyze_dataset(df):
    return df.describe()

analyze_dataset(sleep)

# %%
metadata={'title':'Sleep Dataset','source':'Workshop Dataset','version':'1.0','variables':['sleep_hours','attention']}
metadata

# %%
datasets=[sleep.copy(),sleep.copy()]
results=[]
for d in datasets:
    results.append(d.describe())
len(results)

# %%
from datetime import datetime
run_log={'timestamp':str(datetime.now()),'dataset_version':'1.0'}
run_log

# %% [markdown]
# ### Faculty Activity 1

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 2

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 3

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 4

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 5

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 6

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 7

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 8

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 9

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 10

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 11

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 12

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 13

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 14

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 15

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 16

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 17

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 18

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 19

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 20

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 21

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 22

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 23

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 24

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 25

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 26

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 27

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 28

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Faculty Activity 29

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %% [markdown]
# ### Faculty Activity 30

# %% [markdown]
# Data -> Analysis -> Documentation -> Automation -> Validation -> Reproducibility

# %%
import tracemalloc,time
tracemalloc.start(); start=time.time(); x=sum(range(10000)); current,peak=tracemalloc.get_traced_memory(); print({'runtime':time.time()-start,'peak':peak})

# %% [markdown]
# ### Strong/Average/Weak Rubric 1

# %% [markdown]
# - Strong: fully documented and reproducible
# - Average: partial documentation
# - Weak: insufficient documentation

# %% [markdown]
# ### Strong/Average/Weak Rubric 2

# %% [markdown]
# - Strong: fully documented and reproducible
# - Average: partial documentation
# - Weak: insufficient documentation

# %% [markdown]
# ### Strong/Average/Weak Rubric 3

# %% [markdown]
# - Strong: fully documented and reproducible
# - Average: partial documentation
# - Weak: insufficient documentation

# %% [markdown]
# ### Strong/Average/Weak Rubric 4

# %% [markdown]
# - Strong: fully documented and reproducible
# - Average: partial documentation
# - Weak: insufficient documentation

# %% [markdown]
# ### Strong/Average/Weak Rubric 5

# %% [markdown]
# - Strong: fully documented and reproducible
# - Average: partial documentation
# - Weak: insufficient documentation

# %% [markdown]
# ### Strong/Average/Weak Rubric 6

# %% [markdown]
# - Strong: fully documented and reproducible
# - Average: partial documentation
# - Weak: insufficient documentation

# %% [markdown]
# ### Strong/Average/Weak Rubric 7

# %% [markdown]
# - Strong: fully documented and reproducible
# - Average: partial documentation
# - Weak: insufficient documentation

# %% [markdown]
# ### Strong/Average/Weak Rubric 8

# %% [markdown]
# - Strong: fully documented and reproducible
# - Average: partial documentation
# - Weak: insufficient documentation
