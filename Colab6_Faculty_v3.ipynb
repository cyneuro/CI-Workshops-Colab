# %% [markdown]
# # Colab6_Faculty_v3
# ## Studio 6: Machine Learning Workflows for Scientific Discovery

# %% [markdown]
# Scientific Question → Data → Features → Model → Prediction → Evaluation → Interpretation → Limitations → Discovery

# %% [markdown]
# ## Instructor Guide

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Learning Outcomes

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Teaching Narrative

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## ML Workflow Overview

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Walkthrough A Classification

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Walkthrough B Regression

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Worked Example 1 Features and Labels

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Worked Example 2 Train Test Split

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Worked Example 3 Decision Trees

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Worked Example 4 Linear Regression

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Worked Example 5 Random Forests

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Worked Example 6 Clustering

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Worked Example 7 Model Evaluation

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Worked Example 8 AI Assisted Discovery

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## ML Evaluation Studio

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Bias and Limitations Studio

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Telemetry Studio

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Scientific Discovery Studio

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## AI Discovery Studio

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Capstone Connections

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Rubrics

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## TA Notes

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Troubleshooting

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Online Delivery

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Stretch Challenge

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %% [markdown]
# ## Advanced Topics

# %% [markdown]
# Faculty guidance, discussion prompts, solutions, assessment notes, and workflow engineering considerations.

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %%
attention_ml=pd.DataFrame({'sleep':[4,5,6,7,8,9,5,6,7,8,4,5],'exercise':[0,1,2,3,4,5,1,2,3,4,0,1],'focus':[0,0,0,1,1,1,0,0,1,1,0,0]})
attention_ml.head()

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
X=attention_ml[['sleep','exercise']]
y=attention_ml['focus']
Xtr,Xte,ytr,yte=train_test_split(X,y,test_size=0.25,random_state=42)
model=DecisionTreeClassifier(max_depth=3).fit(Xtr,ytr)
print(model.score(Xte,yte))

# %%
sleep_reg=pd.DataFrame({'sleep_hours':[4,5,6,7,8,9,5,6,7,8],'attention':[48,55,64,73,80,88,58,67,75,84]})

# %%
from sklearn.linear_model import LinearRegression
X=sleep_reg[['sleep_hours']]
y=sleep_reg['attention']
model=LinearRegression().fit(X,y)
print(model.score(X,y))

# %%
from sklearn.cluster import KMeans
behavior=pd.DataFrame({'sleep':[4,5,6,8,9,4,5,6,8,9],'stress':[8,8,7,4,3,9,8,6,5,3]})
behavior['cluster']=KMeans(n_clusters=3,random_state=42).fit_predict(behavior[['sleep','stress']])
behavior.head()

# %% [markdown]
# ### ML Activity 1

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 2

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 3

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 4

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 5

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 6

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 7

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 8

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 9

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 10

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 11

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 12

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 13

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 14

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 15

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 16

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 17

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 18

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 19

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 20

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 21

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 22

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 23

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 24

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 25

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 26

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 27

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 28

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 29

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 30

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 31

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 32

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 33

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 34

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 35

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 36

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 37

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 38

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 39

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 40

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 41

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 42

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 43

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 44

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 45

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 46

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 47

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 48

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ### ML Activity 49

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); import numpy as np; arr=np.random.randn(100000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### ML Activity 50

# %% [markdown]
# Question → Features → Model → Evaluation → Interpretation → Limitations

# %% [markdown]
# ## Capstone Bridge
# Sleep Analytics, Attention Analytics, Neuro-Inspired Sensors, Smart Campus Wellness workflows with ML-driven discovery.
