# %% [markdown]
# # Colab1_Student_v3 Deep Revision
# ## Studio 1: Scientific Discovery Through Workflows

# %% [markdown]
# Question → Data → Observation → Evidence → Interpretation → Hypothesis → Additional Data Needed → Discovery

# %% [markdown]
# ## Learning Outcomes

# %% [markdown]
# ## Scientific Discovery Framework

# %% [markdown]
# ## One Question Many Workflows

# %% [markdown]
# ## What Counts as Evidence

# %% [markdown]
# ## Scientific Question Laboratory

# %% [markdown]
# ## Workflow Failure Analysis

# %% [markdown]
# ## AI Workflow Studio

# %% [markdown]
# ## Dataset Marketplace

# %% [markdown]
# ## Visualization Workflow Studio

# %% [markdown]
# ## Statistical Workflow Studio

# %% [markdown]
# ## Machine Learning Workflow Studio

# %% [markdown]
# ## Cloud Workflow Studio

# %% [markdown]
# ## Edge Workflow Studio

# %% [markdown]
# ## Bring Your Own Dataset

# %% [markdown]
# ## Discovery Reflection Journal

# %% [markdown]
# ## Capstone Connections

# %% [markdown]
# ## Stretch Challenge

# %% [markdown]
# Import libraries

# %%
import pandas as pd, matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset Laboratory: Sleep
# What questions can be answered? What workflow would you choose?

# %%
pd.DataFrame({'sleep_hours': [4, 5, 6, 7, 8, 9], 'attention': [52, 58, 66, 74, 82, 89]})

# %% [markdown]
# ## Dataset Laboratory: Exercise
# What questions can be answered? What workflow would you choose?

# %%
pd.DataFrame({'exercise_minutes': [0, 10, 20, 30, 40, 60], 'mood_score': [45, 50, 55, 65, 70, 80]})

# %% [markdown]
# ## Dataset Laboratory: Study
# What questions can be answered? What workflow would you choose?

# %%
pd.DataFrame({'study_hours': [1, 2, 3, 4, 5, 6], 'exam_score': [55, 60, 68, 75, 80, 85]})

# %% [markdown]
# ## Dataset Laboratory: Campus
# What questions can be answered? What workflow would you choose?

# %%
pd.DataFrame({'temperature': [68, 70, 72, 74, 76], 'occupancy': [20, 35, 50, 65, 80]})

# %% [markdown]
# ### Reflection 1
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 2
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 3
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 4
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 5
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 6
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 7
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 8
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 9
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 10
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 11
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 12
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 13
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 14
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 15
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 16
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 17
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 18
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 19
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 20
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 21
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 22
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 23
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 24
# Question:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ### Reflection 25
# Question:
# Evidence:
# Interpretation:
# Next Question:
