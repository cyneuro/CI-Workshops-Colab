# %% [markdown]
# # Colab5_Faculty_v3
# ## Studio 5: Scaling Scientific Workflows Using Cloud and HPC Resources

# %% [markdown]
# Workflow: Scientific Question → Dataset → Analysis → Runtime Measurement → Resource Requirements → Scaling Strategy → Cloud/HPC Deployment → Benchmarking → Discovery

# %% [markdown]
# ## Instructor Guide

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Learning Outcomes

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Cloud and HPC Overview

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Workflow Scaling Narrative

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Walkthrough A Runtime Growth

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Walkthrough B Scaling Sleep Analytics

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Worked Example 1 Serial vs Parallel

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Worked Example 2 Runtime Benchmarking

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Worked Example 3 Memory Profiling

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Worked Example 4 Large Dataset Processing

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Worked Example 5 Cloud Deployment Models

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Worked Example 6 HPC Queues and Jobs

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Worked Example 7 Distributed Cyberinfrastructure

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Worked Example 8 Scaling ML Workflows

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Benchmarking Studio

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Telemetry Studio

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Cloud HPC Decision Studio

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## FABRIC CloudLab Chameleon Concepts

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## AI Assisted Scaling Studio

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Rubrics

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## TA Notes

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Troubleshooting

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Online Delivery

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Stretch Challenge

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %% [markdown]
# ## Advanced Topics

# %% [markdown]
# Faculty notes, teaching guidance, worked solutions, prompts, and assessment recommendations.

# %%
import pandas as pd, numpy as np, time, tracemalloc, matplotlib.pyplot as plt

# %%
sizes=[1000,10000,100000];
for n in sizes:
 import time; start=time.time(); sum(range(n)); print(n,time.time()-start)

# %%
sleep=pd.DataFrame({'sleep_hours':[4,5,6,7,8,9]*1000,'attention':[52,58,66,74,82,89]*1000}); sleep.head()

# %%
tracemalloc.start(); x=np.random.randn(1000000); print(tracemalloc.get_traced_memory()[1])

# %%
from sklearn.linear_model import LinearRegression
X=np.arange(1000).reshape(-1,1); y=2*X.ravel()+1
LinearRegression().fit(X,y)

# %% [markdown]
# ### Scaling Activity 1

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 2

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 3

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 4

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 5

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 6

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 7

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 8

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 9

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 10

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 11

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 12

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 13

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 14

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 15

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 16

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 17

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 18

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 19

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 20

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 21

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 22

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 23

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 24

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 25

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 26

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 27

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 28

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 29

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 30

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 31

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 32

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 33

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 34

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 35

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 36

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 37

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 38

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 39

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 40

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 41

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 42

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 43

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %%
import time; start=time.time(); x=sum(range(500000)); print('runtime',time.time()-start)

# %% [markdown]
# ### Scaling Activity 44

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ### Scaling Activity 45

# %% [markdown]
# Measure runtime, memory, throughput, bottlenecks, scalability, and deployment strategy.

# %% [markdown]
# ## Capstone Bridge
# Sleep Analytics, Attention Analytics, Neuro-Inspired Sensor Workflows, Smart Campus Wellness.
