# %% [markdown]
# # Colab1_Faculty_v3 Deep Revision
# ## Studio 1: Scientific Discovery Through Workflows

# %% [markdown]
# Core Thread: Question → Data → Observation → Evidence → Interpretation → Hypothesis → Additional Data Needed → Discovery

# %% [markdown]
# ## Instructor Guide

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Learning Outcomes

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Teaching Narrative

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Scientific Discovery Framework

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## One Question Many Workflows

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## What Counts as Evidence

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Scientific Question Laboratory

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Workflow Failure Analysis

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## AI Workflow Studio

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Dataset Marketplace

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Visualization Workflow Studio

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Statistical Workflow Studio

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Machine Learning Workflow Studio

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Cloud Workflow Studio

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Edge Workflow Studio

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Bring Your Own Dataset

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Discovery Reflection Journal

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Capstone Connections

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## Rubrics

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %% [markdown]
# ## TA Notes

# %% [markdown]
# Faculty prompts, discussion guidance, solutions, and assessment support.

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset Laboratory: Sleep

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'sleep_hours':[4,5,6,7,8,9],'attention':[52,58,66,74,82,89]}); display(df)

# %% [markdown]
# ## Dataset Laboratory: Exercise

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'exercise_minutes':[0,10,20,30,40,60],'mood_score':[45,50,55,65,70,80]}); display(df)

# %% [markdown]
# ## Dataset Laboratory: Study

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'study_hours':[1,2,3,4,5,6],'exam_score':[55,60,68,75,80,85]}); display(df)

# %% [markdown]
# ## Dataset Laboratory: Campus

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'temperature':[68,70,72,74,76],'occupancy':[20,35,50,65,80]}); display(df)

# %% [markdown]
# ## Dataset Laboratory: Health

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'steps':[4000,5000,6000,8000,10000],'resting_hr':[85,80,75,72,68]}); display(df)

# %% [markdown]
# ## Dataset Laboratory: Neuro

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'age':[20,30,40,50,60],'reaction_time':[300,320,340,375,410]}); display(df)

# %% [markdown]
# ## Dataset Laboratory: EEG

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'time':[1,2,3,4,5],'signal':[0.2,0.4,0.3,0.5,0.7]}); display(df)

# %% [markdown]
# ## Dataset Laboratory: Environment

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'humidity':[30,35,40,50,60],'air_quality':[85,82,78,70,60]}); display(df)

# %% [markdown]
# ## Dataset Laboratory: Social

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'hours_online':[1,2,3,4,5],'stress':[40,45,48,60,75]}); display(df)

# %% [markdown]
# ## Dataset Laboratory: Nutrition

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'fruit_servings':[0,1,2,3,4],'wellbeing':[55,60,68,74,80]}); display(df)

# %% [markdown]
# ## Dataset Laboratory: Sports

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'training_hours':[2,4,6,8,10],'performance':[50,60,72,82,90]}); display(df)

# %% [markdown]
# ## Dataset Laboratory: Sensors

# %% [markdown]
# Generate answerable, partially answerable, and non-answerable questions. Design visualization, statistical, ML, cloud, and edge workflows.

# %%
df=pd.DataFrame({'light':[120,130,140,160,180],'activity':[10,15,20,25,32]}); display(df)

# %% [markdown]
# ### Discovery Challenge 1

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 2

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 3

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 4

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 5

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %%
import time; start=time.time(); x=sum(range(100000)); print('workflow telemetry',time.time()-start)

# %% [markdown]
# ### Discovery Challenge 6

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 7

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 8

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 9

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 10

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %%
import time; start=time.time(); x=sum(range(100000)); print('workflow telemetry',time.time()-start)

# %% [markdown]
# ### Discovery Challenge 11

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 12

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 13

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 14

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 15

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %%
import time; start=time.time(); x=sum(range(100000)); print('workflow telemetry',time.time()-start)

# %% [markdown]
# ### Discovery Challenge 16

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 17

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 18

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 19

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 20

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %%
import time; start=time.time(); x=sum(range(100000)); print('workflow telemetry',time.time()-start)

# %% [markdown]
# ### Discovery Challenge 21

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 22

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 23

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 24

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 25

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %%
import time; start=time.time(); x=sum(range(100000)); print('workflow telemetry',time.time()-start)

# %% [markdown]
# ### Discovery Challenge 26

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 27

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 28

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 29

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 30

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %%
import time; start=time.time(); x=sum(range(100000)); print('workflow telemetry',time.time()-start)

# %% [markdown]
# ### Discovery Challenge 31

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 32

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 33

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 34

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 35

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %%
import time; start=time.time(); x=sum(range(100000)); print('workflow telemetry',time.time()-start)

# %% [markdown]
# ### Discovery Challenge 36

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 37

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 38

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 39

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %% [markdown]
# ### Discovery Challenge 40

# %% [markdown]
# Question → Dataset Choice → Workflow Choice → Evidence → Interpretation → Next Question

# %%
import time; start=time.time(); x=sum(range(100000)); print('workflow telemetry',time.time()-start)
