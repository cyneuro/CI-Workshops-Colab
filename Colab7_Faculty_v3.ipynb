# %% [markdown]
# # Colab7_Faculty_v3
# ## Studio 7: Cloud-to-Edge Scientific Workflows and Embedded Analytics

# %% [markdown]
# Scientific Question → Sensors → Edge Device → Local Analytics → Cloud Analytics → Machine Learning → Visualization → Decision Support → Discovery

# %% [markdown]
# ## Instructor Guide

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Learning Outcomes

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Teaching Narrative

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Edge Computing Overview

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Walkthrough A Sensor Data Collection

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Walkthrough B Smart Campus Wellness Workflow

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Worked Example 1 Edge vs Cloud

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Worked Example 2 Sensor Acquisition

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Worked Example 3 Embedded Analytics

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Worked Example 4 Telemetry and Monitoring

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Worked Example 5 Cloud-to-Edge Workflows

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Worked Example 6 AI at the Edge

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Worked Example 7 Workflow Deployment

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Worked Example 8 Smart Campus Decision Support

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Edge Analytics Studio

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Sensor Workflow Studio

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Cloud-to-Edge Design Studio

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## AI-Assisted Edge Workflow Studio

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Telemetry Studio

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Smart Campus Studio

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Neuro-Inspired Sensor Studio

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Rubrics

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## TA Notes

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Troubleshooting

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Online Delivery

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Stretch Challenge

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %% [markdown]
# ## Advanced Topics

# %% [markdown]
# Faculty guidance, solutions, discussion prompts, assessment notes, and implementation ideas.

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %%
sensors=pd.DataFrame({'temperature':[70,71,72,74,76,78], 'humidity':[55,54,53,52,50,49], 'light':[120,130,140,160,180,190]}); sensors

# %%
sensors.plot(); plt.show()

# %%
wellness=pd.DataFrame({'occupancy':[20,30,50,80,100],'temperature':[70,72,75,79,82],'alert':[0,0,0,1,1]}); wellness

# %%
from sklearn.ensemble import RandomForestClassifier
X=wellness[['occupancy','temperature']]
y=wellness['alert']
model=RandomForestClassifier(random_state=42).fit(X,y)
print('edge model ready')

# %% [markdown]
# ### Edge Activity 1

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 2

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 3

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 4

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 5

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 6

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 7

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 8

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 9

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 10

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 11

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 12

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 13

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 14

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 15

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 16

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 17

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 18

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 19

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 20

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 21

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 22

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 23

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 24

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 25

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 26

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 27

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 28

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 29

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 30

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 31

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 32

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 33

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 34

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 35

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 36

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 37

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 38

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 39

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 40

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 41

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 42

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 43

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 44

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 45

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 46

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 47

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 48

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ### Edge Activity 49

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %%
import time,tracemalloc; tracemalloc.start(); start=time.time(); data=np.random.randn(50000); print({'runtime':time.time()-start,'peak':tracemalloc.get_traced_memory()[1]})

# %% [markdown]
# ### Edge Activity 50

# %% [markdown]
# Sensors → Edge Processing → Cloud Analytics → Decision Support

# %% [markdown]
# ## Capstone Integration
# Sleep Analytics, Attention Analytics, Neuro-Inspired Sensors, Smart Campus Wellness, micro:bit-based edge workflows.
