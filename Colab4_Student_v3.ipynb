# %% [markdown]
# # Colab4_Student_v3
# ## Studio 4: Workflow Automation, Metadata, and Reproducible Research

# %% [markdown]
# ### Learning Outcomes
# - Describe scientific workflows
# - Automate analysis steps
# - Create metadata records
# - Explain provenance
# - Evaluate reproducibility
# - Measure workflow performance

# %% [markdown]
# ## Workflow Narrative
# Scientific Question → Data Discovery → Data Acquisition → Analysis → Documentation → Automation → Validation → Reproducibility

# %% [markdown]
# In Studio 3 you analyzed data. In Studio 4 you will make analyses repeatable, reusable, and reproducible.

# %%
import pandas as pd, numpy as np, json, time

# %% [markdown]
# ## Walkthrough A: From Manual Analysis to Workflow

# %%
sleep=pd.DataFrame({'sleep_hours':[4,5,6,7,8,9],'attention':[52,58,66,74,82,89]})
sleep

# %%
sleep.describe()

# %%
def analyze_dataset(df):
    return df.describe()

analyze_dataset(sleep)

# %% [markdown]
# Reflection: Why is the function-based approach easier to reuse?

# %% [markdown]
# ## Walkthrough B: Metadata Matters

# %%
metadata={'title':'Sleep Dataset','source':'Workshop Dataset','version':'1.0'}
metadata

# %% [markdown]
# What metadata exists? What metadata is missing? Why does it matter?

# %% [markdown]
# ## Manual vs Automated Workflow

# %% [markdown]
# Complete the activity and record reflections.

# %% [markdown]
# ## Workflow Decomposition

# %% [markdown]
# Complete the activity and record reflections.

# %% [markdown]
# ## Function-Based Automation

# %% [markdown]
# Complete the activity and record reflections.

# %% [markdown]
# ## Batch Processing

# %% [markdown]
# Complete the activity and record reflections.

# %% [markdown]
# ## Run Tracking

# %% [markdown]
# Complete the activity and record reflections.

# %% [markdown]
# ## Metadata Records

# %% [markdown]
# Complete the activity and record reflections.

# %% [markdown]
# ## AI Workflow Generation

# %% [markdown]
# Complete the activity and record reflections.

# %% [markdown]
# ## Reproducibility Evaluation

# %% [markdown]
# Complete the activity and record reflections.

# %%
datasets=[sleep.copy(),sleep.copy()]
for d in datasets:
    print(d.shape)

# %%
from datetime import datetime
run_log={'timestamp':str(datetime.now())}
run_log

# %% [markdown]
# ## Workflow Automation Studio

# %% [markdown]
# Convert notebook steps into a workflow diagram: Acquire → Clean → Analyze → Visualize → Report

# %% [markdown]
# ## Metadata Studio

# %%
metadata={'dataset':'sleep','author':'student','version':'1.0'}
metadata

# %% [markdown]
# Expand this metadata record.

# %% [markdown]
# ## AI Workflow Studio

# %% [markdown]
# Ask AI to design a scientific workflow. Evaluate missing steps and assumptions.

# %% [markdown]
# ## Provenance Studio

# %% [markdown]
# Raw Data → Cleaned Data → Analysis → Figures → Report

# %% [markdown]
# ## Reproducibility Studio

# %% [markdown]
# Evaluate whether a workflow is Strong, Average, or Weak.

# %% [markdown]
# ## Telemetry

# %%
import tracemalloc,time
tracemalloc.start()
start=time.time()
_ = sleep.describe()
print('Runtime:',time.time()-start)
print('Peak Memory:',tracemalloc.get_traced_memory()[1])

# %% [markdown]
# Why does telemetry matter for large workflows and HPC systems?

# %% [markdown]
# ### Reflection 1
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 2
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 3
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 4
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 5
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 6
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 7
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 8
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 9
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 10
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 11
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 12
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 13
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 14
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ### Reflection 15
# Document observations, evidence, limitations, and next steps.

# %% [markdown]
# ## Evidence-Based Communication

# %% [markdown]
# Describe what was done, why it was done, and limitations.

# %% [markdown]
# ## Stretch Challenge

# %% [markdown]
# Design a reproducible workflow for Sleep Analytics, Attention Analytics, Neuro-Inspired Sensor Analytics, or Smart Campus Wellness.

# %% [markdown]
# ## Preview of Studio 5

# %% [markdown]
# Cloud Computing, HPC Scaling, Distributed Cyberinfrastructure, and Workflow Performance.
