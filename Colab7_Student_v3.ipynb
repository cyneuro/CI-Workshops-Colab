# %% [markdown]
# # Colab7_Student_v3
# ## Studio 7: Cloud-to-Edge Scientific Workflows and Embedded Analytics

# %% [markdown]
# ### Learning Outcomes
# - Explain edge and cloud computing
# - Collect and analyze sensor data
# - Design cloud-to-edge workflows
# - Evaluate telemetry
# - Apply embedded analytics concepts

# %% [markdown]
# ## Workflow Narrative
# Scientific Question → Sensors → Edge Device → Local Analytics → Cloud Analytics → Machine Learning → Visualization → Decision Support → Discovery

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# ## Walkthrough A: Sensor Data Collection Workflow

# %%
sensors=pd.DataFrame({'temperature':[70,71,72,74,76,78],'humidity':[55,54,53,52,50,49],'light':[120,130,140,160,180,190]})
sensors

# %%
sensors.plot(figsize=(8,4)); plt.show()

# %% [markdown]
# Observation:
# Evidence:
# Interpretation:
# Next Question:

# %% [markdown]
# ## Walkthrough B: Smart Campus Wellness Workflow

# %%
wellness=pd.DataFrame({'occupancy':[20,30,50,80,100],'temperature':[70,72,75,79,82],'alert':[0,0,0,1,1]})
wellness

# %%
from sklearn.ensemble import RandomForestClassifier
X=wellness[['occupancy','temperature']]
y=wellness['alert']
model=RandomForestClassifier(random_state=42).fit(X,y)
print('Model trained')

# %% [markdown]
# ## Edge vs Cloud Computing

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Sensor Data Acquisition

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Embedded Analytics

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Telemetry and Monitoring

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Cloud-to-Edge Workflows

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## AI at the Edge

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Workflow Deployment

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Smart Campus Decision Support

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Edge Analytics Studio

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Sensor Workflow Studio

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Cloud-to-Edge Design Studio

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## AI-Assisted Edge Workflow Studio

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Telemetry Studio

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Smart Campus Studio

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %% [markdown]
# ## Neuro-Inspired Sensor Studio

# %% [markdown]
# Complete the activity and record observations, evidence, interpretations, and limitations.

# %%
import time,tracemalloc
tracemalloc.start()
start=time.time()
arr=np.random.randn(50000)
print('Runtime',time.time()-start)
print('Peak Memory',tracemalloc.get_traced_memory()[1])

# %% [markdown]
# ### Reflection 1
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 2
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 3
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 4
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 5
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 6
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 7
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 8
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 9
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 10
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 11
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 12
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 13
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 14
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 15
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 16
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 17
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 18
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 19
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ### Reflection 20
# Sensors:
# Edge Processing:
# Cloud Processing:
# Decision Support:
# Discovery:

# %% [markdown]
# ## Capstone Connections
# Sleep Analytics, Attention Analytics, Neuro-Inspired Sensors, Smart Campus Wellness, and micro:bit workflows.

# %% [markdown]
# ## Stretch Challenge
# Design and diagram a complete cloud-to-edge workflow.

# %% [markdown]
# ## Preview of Studio 8
# FAIR, Provenance, Benchmarking, and Workflow Validation.
