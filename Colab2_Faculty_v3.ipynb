# %% [markdown]
# # Colab2_Faculty_v3 Deep Revision
# ## Studio 2: Open Data Discovery and Neuroinformatics Workflows

# %% [markdown]
# Core Thread: Question → Dataset Discovery → Metadata → Workflow Design → Evidence → Interpretation → Discovery

# %% [markdown]
# ## Instructor Guide

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Learning Outcomes

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Teaching Narrative

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Repository Comparison Studio

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Dataset Detective Lab

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Metadata Exploration Studio

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Dataset Selection Studio

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Scientific Question Laboratory

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## AI Dataset Discovery Studio

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Missing Data Challenge

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Competing Datasets Challenge

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Workflow Planning Studio

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## OpenNeuro Exploration

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## DANDI Exploration

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Allen Brain Observatory Exploration

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Dataset Marketplace

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Bring Your Own Dataset

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Capstone Connections

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## Rubrics

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %% [markdown]
# ## TA Notes

# %% [markdown]
# Faculty notes, solutions, prompts, rubrics, and discussion guidance.

# %%
import pandas as pd

# %% [markdown]
# ## Repository Laboratory: OpenNeuro

# %% [markdown]
# Data Type: Neuroimaging. Generate questions, inspect metadata, design workflows, identify limitations.

# %% [markdown]
# ## Repository Laboratory: DANDI

# %% [markdown]
# Data Type: Neurophysiology. Generate questions, inspect metadata, design workflows, identify limitations.

# %% [markdown]
# ## Repository Laboratory: Allen Brain Observatory

# %% [markdown]
# Data Type: Brain activity and behavior. Generate questions, inspect metadata, design workflows, identify limitations.

# %%
metadata={'sample_size': 1000, 'variables': ['sleep', 'attention'], 'year': 2025}
print('Sleep Dataset')
print(metadata)

# %%
metadata={'sample_size': 100, 'variables': ['signal', 'task'], 'year': 2024}
print('EEG Dataset')
print(metadata)

# %%
metadata={'sample_size': 500, 'variables': ['temperature', 'humidity'], 'year': 2026}
print('Sensor Dataset')
print(metadata)

# %%
metadata={'sample_size': 2000, 'variables': ['occupancy', 'air_quality'], 'year': 2025}
print('Campus Dataset')
print(metadata)

# %% [markdown]
# ## Dataset Detective Case 1

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ## Dataset Detective Case 2

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ## Dataset Detective Case 3

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ## Dataset Detective Case 4

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ## Dataset Detective Case 5

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ## Dataset Detective Case 6

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ## Dataset Detective Case 7

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ## Dataset Detective Case 8

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ## Dataset Detective Case 9

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ## Dataset Detective Case 10

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ## Dataset Detective Case 11

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ## Dataset Detective Case 12

# %% [markdown]
# Determine possible research questions, populations, variables, missing data, and workflow choices.

# %% [markdown]
# ### Discovery Exercise 1

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 2

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 3

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 4

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 5

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 6

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 7

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 8

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 9

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 10

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 11

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 12

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 13

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 14

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 15

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 16

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 17

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 18

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 19

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 20

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 21

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 22

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 23

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 24

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 25

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 26

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 27

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 28

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 29

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 30

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 31

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 32

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 33

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 34

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 35

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 36

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 37

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 38

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 39

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery

# %% [markdown]
# ### Discovery Exercise 40

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow → Evidence → Discovery
