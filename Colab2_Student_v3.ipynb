# %% [markdown]
# # Colab2_Student_v3 Deep Revision
# ## Studio 2: Open Data Discovery and Neuroinformatics Workflows

# %% [markdown]
# Question → Dataset Discovery → Metadata → Workflow Design → Evidence → Interpretation → Discovery

# %% [markdown]
# ## Learning Outcomes

# %% [markdown]
# ## Repository Comparison Studio

# %% [markdown]
# ## Dataset Detective Lab

# %% [markdown]
# ## Metadata Exploration

# %% [markdown]
# ## Dataset Selection Studio

# %% [markdown]
# ## Scientific Question Laboratory

# %% [markdown]
# ## AI Dataset Discovery Studio

# %% [markdown]
# ## Missing Data Challenge

# %% [markdown]
# ## Competing Datasets Challenge

# %% [markdown]
# ## Workflow Planning Studio

# %% [markdown]
# ## OpenNeuro Exploration

# %% [markdown]
# ## DANDI Exploration

# %% [markdown]
# ## Allen Brain Observatory Exploration

# %% [markdown]
# ## Dataset Marketplace

# %% [markdown]
# ## Bring Your Own Dataset

# %% [markdown]
# ## Capstone Connections

# %% [markdown]
# ## Stretch Challenge

# %%
import pandas as pd

# %% [markdown]
# ### Repository Comparison

# %%
pd.DataFrame({'Repository':['OpenNeuro','DANDI','Allen Brain Observatory'],'Focus':['Neuroimaging','Neurophysiology','Brain Activity']})

# %% [markdown]
# ## Dataset Detective Case 1
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ## Dataset Detective Case 2
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ## Dataset Detective Case 3
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ## Dataset Detective Case 4
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ## Dataset Detective Case 5
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ## Dataset Detective Case 6
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ## Dataset Detective Case 7
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ## Dataset Detective Case 8
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ## Dataset Detective Case 9
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ## Dataset Detective Case 10
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ## Dataset Detective Case 11
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ## Dataset Detective Case 12
# Identify possible questions, variables, missing information, and workflows.

# %% [markdown]
# ### Discovery Reflection 1
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 2
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 3
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 4
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 5
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 6
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 7
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 8
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 9
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 10
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 11
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 12
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 13
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 14
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 15
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 16
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 17
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 18
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 19
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 20
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 21
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 22
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 23
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 24
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:

# %% [markdown]
# ### Discovery Reflection 25
# Dataset:
# Metadata:
# Workflow:
# Evidence:
# Discovery:
