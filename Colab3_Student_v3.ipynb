# %% [markdown]
# # Colab3_Student_v3
# ## Studio 3: AI-Assisted Data Analysis and Visualization

# %% [markdown]
# ### Learning Outcomes
# - Analyze scientific datasets
# - Create visualizations
# - Interpret evidence
# - Evaluate AI-generated insights
# - Develop scientific questions
# - Communicate findings responsibly

# %% [markdown]
# ## Scientific Discovery Framework
# Scientific Question → Data → Observation → Evidence → Interpretation → Hypothesis → Additional Data Needed → Discovery

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset Exploration

# %%
participants=pd.DataFrame({'participant_id':range(1,21),'age':[18,19,20,21,22,23,24,25,27,29,31,33,35,40,45,50,55,60,65,70],'sex':['F','M']*10})
participants.head()

# %% [markdown]
# What variables are available? What variables are missing?

# %% [markdown]
# ## Walkthrough A: Exploring Age Distribution

# %%
participants['age'].hist(bins=8); plt.show()

# %% [markdown]
# Observation:
#
# Evidence:
#
# Interpretation:
#
# Limitation:
#
# Next Question:

# %% [markdown]
# ## Multiple Visualizations

# %%
participants['age'].plot(kind='hist'); plt.show()

# %%
participants.boxplot(column='age'); plt.show()

# %%
participants['sex'].value_counts().plot(kind='bar'); plt.show()

# %%
participants.describe()

# %% [markdown]
# What did each visualization reveal?

# %% [markdown]
# ## Walkthrough B: Dataset Limitations

# %% [markdown]
# What can be studied?
#
# What cannot be studied?
#
# Why?

# %% [markdown]
# ## Observation vs Interpretation

# %% [markdown]
# Student activity and reflection.

# %% [markdown]
# ## Answerable Questions

# %% [markdown]
# Student activity and reflection.

# %% [markdown]
# ## Correlation vs Causation

# %% [markdown]
# Student activity and reflection.

# %% [markdown]
# ## Visualization Comparison

# %% [markdown]
# Student activity and reflection.

# %% [markdown]
# ## Question Generation

# %% [markdown]
# Student activity and reflection.

# %% [markdown]
# ## Designing the Next Study

# %% [markdown]
# Student activity and reflection.

# %% [markdown]
# ## AI Hallucination Detection

# %% [markdown]
# Student activity and reflection.

# %% [markdown]
# ## Evidence-Based Writing

# %% [markdown]
# Student activity and reflection.

# %%
sleep_df=pd.DataFrame({'sleep_hours':[4,5,6,7,8,9,5,6,7,8],'attention_score':[50,55,65,72,80,88,58,67,75,84]})

# %%
plt.scatter(sleep_df.sleep_hours,sleep_df.attention_score); plt.show()

# %% [markdown]
# Does the graph show causation? Why or why not?

# %% [markdown]
# ## Scientific Question Studio

# %% [markdown]
# Create answerable, partially answerable, and not answerable questions.

# %% [markdown]
# Create answerable, partially answerable, and not answerable questions.

# %% [markdown]
# Create answerable, partially answerable, and not answerable questions.

# %% [markdown]
# ## AI Discovery Studio

# %% [markdown]
# Ask AI to generate 10 scientific questions and classify them.

# %% [markdown]
# ## AI Hallucination Case Study

# %% [markdown]
# Identify unsupported inference, causal claim, missing evidence, invented conclusion.

# %% [markdown]
# ## Evidence-Based Communication Studio

# %% [markdown]
# Rewrite weak claims into evidence-based statements.

# %% [markdown]
# ## Telemetry

# %%
import time,tracemalloc
tracemalloc.start()
start=time.time()
summary=sleep_df.describe()
print('runtime',time.time()-start)
print('peak',tracemalloc.get_traced_memory()[1])
summary

# %% [markdown]
# ## ML Workflow Preview

# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
attention_ml=pd.DataFrame({'sleep_hours':[4,5,6,7,8,9,5,6],'exercise_days':[0,1,2,3,4,5,1,2],'attention_level':[0,0,0,1,1,1,0,0]})
attention_ml.head()

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# Prediction is not explanation. Why?

# %% [markdown]
# ### Reflection 1
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 2
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 3
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 4
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 5
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 6
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 7
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 8
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 9
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 10
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 11
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 12
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 13
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 14
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 15
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 16
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 17
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 18
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 19
# Where are we in the discovery process?

# %% [markdown]
# ### Reflection 20
# Where are we in the discovery process?

# %% [markdown]
# ## Stretch Challenge
# Design a Sleep Analytics, Attention Analytics, Neuro-Inspired Sensor, or Smart Campus Wellness workflow.

# %% [markdown]
# ## Preview of Studios 4-8
# Cloud/HPC, ML, Cloud-to-Edge, FAIR, Provenance, Validation.
